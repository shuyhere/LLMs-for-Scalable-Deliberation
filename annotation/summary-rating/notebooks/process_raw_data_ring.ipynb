# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import markdown
from markdown.extensions import codehilite

# %%
df = pd.read_csv('../data_files/raw/summaries_V0903_for_humanstudy_detail.csv')

# %%
df.model.unique()
# Out:
# array(['deepseek-chat', 'gemini-2.5-pro', 'gpt-5', 'qwen3-32b',
#        'web-rev-claude-opus-4-20250514'], dtype=object)

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                    id                            topic  \
# 0    c763306fb89c8d1a  Binary-Online-Identity-Policies
# 1    3db5a5a65e677bcd        Binary-Health-Care-Policy
# 2    db729d705199164d     Openqa-AI-changes-human-life
# 3    ad3135722c23a68f  Binary-Online-Identity-Policies
# 4    9e4326748941154d        Binary-Health-Care-Policy
# ..                ...                              ...
# 745  586806a26aa4cbb2             Binary-Tariff-Policy
# 746  4d430c1bb5afeec0        Binary-Health-Care-Policy
# 747  620f1aea54fb96a7             Binary-Tariff-Policy
# 748  f0835ba6b89f9dc2  Binary-Online-Identity-Policies
# 749  fdb822cbba17c0f2        Binary-Health-Care-Policy
#
#                                               question  \
# 0    Do you support requiring real-name registratio...
# 1    Do you support the government provide basic he...
# 2    How has AI changed your life? Please answer br...
# 3    Do you support requiring real-name registratio...
# 4    Do you support the government provide basic he...
# ..                                                 ...
# 745  Do you think the current tariff policy under t...
# 746  Do you support the government provide basic he...
# 747  Do you think the current tariff policy under t...
# 748  Do you support requiring real-name registratio...
# 749  Do you support the government provide basic he...
#
#                                                summary  \
# 0    Overall summary:\n- Sentiment: Opposition domi...
# 1    Overall summary of the comments:\n\n- Overall ...
# 2    Overall, the comments reflect a positive recep...
# 3    Here is a summary of the comments provided:\n\...
# 4    Based on the comments provided, here is an ove...
# ..                                                 ...
# 745  Overall summary of the comments:\n\n- Sentimen...
# 746  ## Summary of Comments on Government-Provided ...
# 747  ## Summary of Comments on Current Tariff Polic...
# 748  ## Summary of Comments on Real-Name Registrati...
# 749  ## Summary of Comments on Government-Provided ...
#
#                               model  comment_num  \
# 0                             gpt-5           10
# 1                             gpt-5           90
# 2                     deepseek-chat           10
# 3                    gemini-2.5-pro           10
# 4                    gemini-2.5-pro           90
# ..                              ...          ...
# 745                           gpt-5           70
# 746  web-rev-claude-opus-4-20250514           30
# 747  web-rev-claude-opus-4-20250514           70
# 748  web-rev-claude-opus-4-20250514           50
# 749  web-rev-claude-opus-4-20250514           10
#
#                                               comments  num_samples_group  \
# 0    0: No I don’t support it. I think it’s fine to...                 10
# 1    0: Yes, I think government based healthcare is...                 90
# 2    0: Al changed my life by making my daily tasks...                 10
# 3    0: No I don’t support it. I think it’s fine to...                 10
# 4    0: Yes, I think government based healthcare is...                 90
# ..                                                 ...                ...
# 745  0: i think that it will have a negative impact...                 70
# 746  0: Yes, I think government based healthcare is...                 30
# 747  0: i think that it will have a negative impact...                 70
# 748  0: No I don’t support it. I think it’s fine to...                 50
# 749  0: Yes, I think government based healthcare is...                 10
#
#      sample_id                     dataset_name  \
# 0            3  Binary-Online-Identity-Policies
# 1            2        Binary-Health-Care-Policy
# 2            1     Openqa-AI-changes-human-life
# 3            3  Binary-Online-Identity-Policies
# 4            1        Binary-Health-Care-Policy
# ..         ...                              ...
# 745          1             Binary-Tariff-Policy
# 746          3        Binary-Health-Care-Policy
# 747          2             Binary-Tariff-Policy
# 748          1  Binary-Online-Identity-Policies
# 749          2        Binary-Health-Care-Policy
#
#                                            source_path
# 0    results/human_judgement/gpt-5/10/Binary-Online...
# 1    results/human_judgement/gpt-5/90/Binary-Health...
# 2    results/human_judgement/deepseek-chat/10/Openq...
# 3    results/human_judgement/gemini-2.5-pro/10/Bina...
# 4    results/human_judgement/gemini-2.5-pro/90/Bina...
# ..                                                 ...
# 745  results/human_judgement/gpt-5/70/Binary-Tariff...
# 746  results/human_judgement/web-rev-claude-opus-4-...
# 747  results/human_judgement/web-rev-claude-opus-4-...
# 748  results/human_judgement/web-rev-claude-opus-4-...
# 749  results/human_judgement/web-rev-claude-opus-4-...
#
# [750 rows x 11 columns]

# %%
# Process the dataframe into the desired format
processed_data = []

for i, (_, row) in enumerate(df.iterrows()):
    raw_id = row['id']
    question = row['question']
    summary = row['summary']
    
    # Add a row for the question
    question_entry = {
        "id": f"{raw_id}_question",
        "raw_id": raw_id,
        "question": question,
        "text": '[Question]' + question.replace("\n", "<br>").replace(" Please answer briefly in 2–3 sentences.", "").replace("Please answer briefly in 1–2 sentences.", ""),
        "model": row['model'],
        "summary_length": row.get('summary_length', None)
    }
    processed_data.append(question_entry)
    
    # Add a row for the summary (convert markdown to HTML using markdown package)
    summary_html = markdown.markdown(summary, extensions=['extra', 'codehilite'])
    summary_entry = {
        "id": f"{raw_id}_summary",
        "raw_id": raw_id,
        "question": question,
        "text": "<h4>Below is a summary of people's opinions on the issue.</h4><hr>" + summary_html,
        "model": row['model'],
        "summary_length": row.get('summary_length', None)
    }
    processed_data.append(summary_entry)

# Convert the processed data into a DataFrame
processed_df = pd.DataFrame(processed_data)

# %%
processed_df
# Out:
#                              id            raw_id  \
# 0     c763306fb89c8d1a_question  c763306fb89c8d1a
# 1      c763306fb89c8d1a_summary  c763306fb89c8d1a
# 2     3db5a5a65e677bcd_question  3db5a5a65e677bcd
# 3      3db5a5a65e677bcd_summary  3db5a5a65e677bcd
# 4     db729d705199164d_question  db729d705199164d
# ...                         ...               ...
# 1495   620f1aea54fb96a7_summary  620f1aea54fb96a7
# 1496  f0835ba6b89f9dc2_question  f0835ba6b89f9dc2
# 1497   f0835ba6b89f9dc2_summary  f0835ba6b89f9dc2
# 1498  fdb822cbba17c0f2_question  fdb822cbba17c0f2
# 1499   fdb822cbba17c0f2_summary  fdb822cbba17c0f2
#
#                                                question  \
# 0     Do you support requiring real-name registratio...
# 1     Do you support requiring real-name registratio...
# 2     Do you support the government provide basic he...
# 3     Do you support the government provide basic he...
# 4     How has AI changed your life? Please answer br...
# ...                                                 ...
# 1495  Do you think the current tariff policy under t...
# 1496  Do you support requiring real-name registratio...
# 1497  Do you support requiring real-name registratio...
# 1498  Do you support the government provide basic he...
# 1499  Do you support the government provide basic he...
#
#                                                    text  \
# 0     [Question]Do you support requiring real-name r...
# 1     <h4>Below is a summary of people's opinions on...
# 2     [Question]Do you support the government provid...
# 3     <h4>Below is a summary of people's opinions on...
# 4               [Question]How has AI changed your life?
# ...                                                 ...
# 1495  <h4>Below is a summary of people's opinions on...
# 1496  [Question]Do you support requiring real-name r...
# 1497  <h4>Below is a summary of people's opinions on...
# 1498  [Question]Do you support the government provid...
# 1499  <h4>Below is a summary of people's opinions on...
#
#                                model summary_length
# 0                              gpt-5           None
# 1                              gpt-5           None
# 2                              gpt-5           None
# 3                              gpt-5           None
# 4                      deepseek-chat           None
# ...                              ...            ...
# 1495  web-rev-claude-opus-4-20250514           None
# 1496  web-rev-claude-opus-4-20250514           None
# 1497  web-rev-claude-opus-4-20250514           None
# 1498  web-rev-claude-opus-4-20250514           None
# 1499  web-rev-claude-opus-4-20250514           None
#
# [1500 rows x 6 columns]

# %%
processed_df['text'].value_counts()[:10]
# Out:
# text
# [Question]What is your opinion on internet influencers (e.g., streamers, bloggers, short video creators) increasingly becoming a recognized profession?             75
# [Question]Do you support the government accepting more refugees fleeing war or persecution?                                                                         75
# [Question]Do you support the government having the authority to enforce vaccination and quarantine measures during severe epidemics?                                75
# [Question]What is your opinion on the rapid update cycle of electronic products, especially smartphones?                                                            75
# [Question]What is your opinion on tipping, and if given the chance, how would you improve or change the current tipping system?                                     75
# [Question]Do you support the government provide basic health insurance for everyone?                                                                                75
# [Question]Do you think the current tariff policy under the Trump administration will have a positive or negative impact on the overall U.S. economy and society?    75
# [Question]Do you support requiring real-name registration on social media platforms, where users must register and post under their real identity?                  75
# [Question]What are your thoughts on Trump’s decision to cut academic funding?                                                                                       75
# [Question]How has AI changed your life?                                                                                                                             75
# Name: count, dtype: int64

# %%
# Check data structure before processing pairs
print("Total rows in df:", len(df))
print("Unique questions:", df['question'].nunique())
print("Unique models:", df['model'].nunique())
print("Unique num_samples_group:", df['num_samples_group'].nunique())

# Check grouping structure
group_sizes = df.groupby(['question', 'num_samples_group']).size()
print("\nGroup sizes (question, num_samples_group):")
print(group_sizes.describe())
print("\nFirst few groups:")
print(group_sizes.head(10))
# Out:
# Total rows in df: 750
# Unique questions: 10
# Unique models: 5
# Unique num_samples_group: 5
#
# Group sizes (question, num_samples_group):
# count    50.0
# mean     15.0
# std       0.0
# min      15.0
# 25%      15.0
# 50%      15.0
# 75%      15.0
# max      15.0
# dtype: float64
#
# First few groups:
# question                                                                                                                                                                          num_samples_group
# Do you support requiring real-name registration on social media platforms, where users must register and post under their real identity? Please answer briefly in 2–3 sentences.  10                   15
#                                                                                                                                                                                   30                   15
#                                                                                                                                                                                   50                   15
#                                                                                                                                                                                   70                   15
#                                                                                                                                                                                   90                   15
# Do you support the government accepting more refugees fleeing war or persecution? Please answer briefly in 2–3 sentences.                                                         10                   15
#                                                                                                                                                                                   30                   15
#                                                                                                                                                                                   50                   15
#                                                                                                                                                                                   70                   15
#                                                                                                                                                                                   90                   15
# dtype: int64

# %%
processed_df.to_csv('../data_files/processed/sum_humanstudy_rating_full.csv', index=False)

# %%
# Build 45 directed ring pairs per (question, num_samples_group), identical schema/HTML to original
import pandas as pd
from pathlib import Path
import markdown

pair_src = Path('/home/ec2-user/LLMs-Scalable-Deliberation/annotation/summary-rating/data_files/processed/sum_humanstudy_pair_full.csv')
rating_src = Path('/home/ec2-user/LLMs-Scalable-Deliberation/annotation/summary-rating/data_files/processed/sum_humanstudy_rating_full.csv')

pair_df = pd.read_csv(pair_src)
rating_df = pd.read_csv(rating_src)
print('Loaded:', len(pair_df), 'pairs,', len(rating_df), 'ratings')

# Build id -> (text, model, length) from rating data
id_to_text = dict(zip(rating_df['id'].astype(str), rating_df['text']))
id_to_model = dict(zip(rating_df['id'].astype(str), rating_df['model']))
id_to_len = dict(zip(rating_df['id'].astype(str), rating_df.get('summary_length', pd.Series([None]*len(rating_df)))))

# Helper: HTML identical to original pair layout

def build_comparison_html(summary_a_html: str, summary_b_html: str) -> str:
    return (
        '<h4>Two summaries of opinions are shown below. Read carefully and answer according to your prior opinion. Both are scrollable.</h4><hr>'
        + "\n        <div style=\"display: flex; gap: 20px;\">\n"
        + '            <div style="flex: 1; border: 1px solid #ccc; padding: 15px; border-radius: 5px;">\n'
        + '                <h4 style="margin-top: 0; color: #2c5aa0;">Summary A</h4>\n'
        + '                <div style="max-height: 800px; overflow-y: auto; padding-right: 10px;">\n'
        + f'                    {summary_a_html}\n'
        + '                </div>\n'
        + '            </div>\n'
        + '            <div style="flex: 1; border: 1px solid #ccc; padding: 15px; border-radius: 5px;">\n'
        + '                <h4 style="margin-top: 0; color: #2c5aa0;">Summary B</h4>\n'
        + '                <div style="max-height: 800px; overflow-y: auto; padding-right: 10px;">\n'
        + f'                    {summary_b_html}\n'
        + '                </div>\n'
        + '            </div>\n'
        + '        </div>'
    )

# Directed ring indices: i -> i+1, i+2, i+3 (mod 15)

def ring_directed_indices(n: int, steps=(1,2,3)):
    for i in range(n):
        for d in steps:
            yield i, (i + d) % n

rows = []
for (question, nsg), g in pair_df.groupby(['question','num_samples_group'], sort=False):
    # Collect the 15 unique summary ids for this group
    ids = pd.unique(pd.concat([g['summary_a_id'], g['summary_b_id']], ignore_index=True).dropna().astype(str))
    if len(ids) < 15:
        # Skip incomplete groups
        continue
    ids = sorted(ids)[:15]  # deterministic order

    for i, j in ring_directed_indices(15, steps=(1,2,3)):
        a_id, b_id = ids[i], ids[j]
        a_text_md = id_to_text.get(a_id, '')
        b_text_md = id_to_text.get(b_id, '')
        a_html = markdown.markdown(a_text_md, extensions=['extra','codehilite'])
        b_html = markdown.markdown(b_text_md, extensions=['extra','codehilite'])
        html = build_comparison_html(a_html, b_html)

        row = {
            'id': f'{a_id}_{b_id}',
            'raw_id': f'{a_id}_{b_id}',
            'question': question,
            'text': html,
            'model': 'comparison',
            'num_samples_group': nsg,
            'summary_length': None,
            'model_a': id_to_model.get(a_id),
            'model_b': id_to_model.get(b_id),
            'summary_a_id': a_id,
            'summary_b_id': b_id,
            'summary_a_text': a_text_md,
            'summary_b_text': b_text_md,
            'summary_length_a': id_to_len.get(a_id),
            'summary_length_b': id_to_len.get(b_id),
        }
        rows.append(row)

ring_df = pd.DataFrame(rows)
print('Built ring pairs:', len(ring_df))
print('Per-group counts (head):')
print(ring_df.groupby(['question','num_samples_group']).size().head())

# Ensure identical column order to original pair_full
cols = ['id','raw_id','question','text','model','num_samples_group','summary_length',
        'model_a','model_b','summary_a_id','summary_b_id','summary_a_text','summary_b_text',
        'summary_length_a','summary_length_b']
for c in cols:
    if c not in ring_df.columns:
        ring_df[c] = None
ring_df = ring_df[cols]

out = Path('/home/ec2-user/LLMs-Scalable-Deliberation/annotation/summary-rating/data_files/processed/sum_humanstudy_pair_full_ring.csv')
ring_df.to_csv(out, index=False)
print('Saved:', out)
# Out:
# Loaded: 4500 pairs, 1500 ratings
# Built ring pairs: 2250
# Per-group counts (head):
# question                                                                                                                                                                          num_samples_group
# Do you support requiring real-name registration on social media platforms, where users must register and post under their real identity? Please answer briefly in 2–3 sentences.  10                   45
#                                                                                                                                                                                   30                   45
#                                                                                                                                                                                   50                   45
#                                                                                                                                                                                   70                   45
#                                                                                                                                                                                   90                   45
# dtype: int64
# Saved: /home/ec2-user/LLMs-Scalable-Deliberation/annotation/summary-rating/data_files/processed/sum_humanstudy_pair_full_ring.csv

# %% [markdown]
# # Produce

# %%
# Load both datasets for natural join
rating_df = pd.read_csv('../data_files/processed/sum_humanstudy_rating_full.csv')
pair_df = pd.read_csv('../data_files/processed/sum_humanstudy_pair_full_ring.csv')

print(f"Rating data shape: {rating_df.shape}")
print(f"Pair data shape: {pair_df.shape}")

# Check the structure
print("\nRating data columns:", rating_df.columns.tolist())
print("Pair data columns:", pair_df.columns.tolist())

print("\nRating data sample:")
print(rating_df.head(3))
print("\nPair data sample:")
print(pair_df.head(3))
# Out:
# Rating data shape: (1500, 6)
# Pair data shape: (2250, 15)
#
# Rating data columns: ['id', 'raw_id', 'question', 'text', 'model', 'summary_length']
# Pair data columns: ['id', 'raw_id', 'question', 'text', 'model', 'num_samples_group', 'summary_length', 'model_a', 'model_b', 'summary_a_id', 'summary_b_id', 'summary_a_text', 'summary_b_text', 'summary_length_a', 'summary_length_b']
#
# Rating data sample:
#                           id            raw_id  \
# 0  c763306fb89c8d1a_question  c763306fb89c8d1a
# 1   c763306fb89c8d1a_summary  c763306fb89c8d1a
# 2  3db5a5a65e677bcd_question  3db5a5a65e677bcd
#
#                                             question  \
# 0  Do you support requiring real-name registratio...
# 1  Do you support requiring real-name registratio...
# 2  Do you support the government provide basic he...
#
#                                                 text  model  summary_length
# 0  [Question]Do you support requiring real-name r...  gpt-5             NaN
# 1  <h4>Below is a summary of people's opinions on...  gpt-5             NaN
# 2  [Question]Do you support the government provid...  gpt-5             NaN
#
# Pair data sample:
#                                   id                             raw_id  \
# 0  38a9bde51b2e82b9_7cb5806a4aa6f3ff  38a9bde51b2e82b9_7cb5806a4aa6f3ff
# 1  38a9bde51b2e82b9_8172525bd422435b  38a9bde51b2e82b9_8172525bd422435b
# 2  38a9bde51b2e82b9_97800d729fb0bca1  38a9bde51b2e82b9_97800d729fb0bca1
#
#                                             question  \
# 0  Do you support requiring real-name registratio...
# 1  Do you support requiring real-name registratio...
# 2  Do you support requiring real-name registratio...
#
#                                                 text       model  \
# 0  <h4>Two summaries of opinions are shown below....  comparison
# 1  <h4>Two summaries of opinions are shown below....  comparison
# 2  <h4>Two summaries of opinions are shown below....  comparison
#
#    num_samples_group  summary_length  model_a  model_b      summary_a_id  \
# 0                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 1                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 2                 10             NaN      NaN      NaN  38a9bde51b2e82b9
#
#        summary_b_id  summary_a_text  summary_b_text  summary_length_a  \
# 0  7cb5806a4aa6f3ff             NaN             NaN               NaN
# 1  8172525bd422435b             NaN             NaN               NaN
# 2  97800d729fb0bca1             NaN             NaN               NaN
#
#    summary_length_b
# 0               NaN
# 1               NaN
# 2               NaN

# %%
# Correct understanding: Both datasets have pairs of rows
# Rating: question + rating summary (2 rows per pair)  
# Pair: question + comparison (2 rows per pair)
# Goal: Create triplets by natural join on raw_id

print("Understanding data structure...")
print(f"Rating data: {len(rating_df)} total rows")
print(f"Pair data: {len(pair_df)} total rows")

# Extract rating pairs (question + summary)
rating_pairs = []
for i in range(0, len(rating_df), 2):
    if i + 1 < len(rating_df):
        question_row = rating_df.iloc[i]
        summary_row = rating_df.iloc[i + 1]
        
        # Verify this is a proper pair
        if (question_row['raw_id'] == summary_row['raw_id'] and 
            '_question' in question_row['id'] and 
            '_summary' in summary_row['id']):
            rating_pairs.append({
                'raw_id': question_row['raw_id'],
                'question': question_row['question'],
                'question_text': question_row['text'],
                'summary_text': summary_row['text'],
                'model': question_row['model'],
                'summary_length': question_row.get('summary_length')
            })

# Debug: Check the pair data structure first
print("Debugging pair data structure...")
print(f"First few rows of pair_df:")
print(pair_df.head(10))
print(f"\nChecking model column values:")
print(pair_df['model'].value_counts())

# Extract pair comparisons (question + comparison)  
pair_comparisons = []
for i in range(0, len(pair_df), 2):
    if i + 1 < len(pair_df):
        question_row = pair_df.iloc[i]
        comparison_row = pair_df.iloc[i + 1]
        
        # Show progress for debugging (only first few and every 100th)
        if i < 20 or i % 200 == 0:
            print(f"Row {i}: model='{question_row['model']}', raw_id='{question_row['raw_id']}'")
            print(f"Row {i+1}: model='{comparison_row['model']}', raw_id='{comparison_row['raw_id']}'")
        
        # Verify this is a proper pair
        # Question row has '_pair_X' suffix, comparison row doesn't
        question_base_id = question_row['raw_id'].rsplit('_pair_', 1)[0] if '_pair_' in question_row['raw_id'] else question_row['raw_id']
        comparison_base_id = comparison_row['raw_id']
        
        if i < 20 or i % 200 == 0:
            print(f"  Comparing: '{question_base_id}' == '{comparison_base_id}'")
        
        if (question_base_id == comparison_base_id and
            question_row['model'] == 'question'):
            pair_comparisons.append({
                'raw_id': comparison_row['raw_id'], 
                'question': question_row['question'],
                'question_text': question_row['text'],
                'comparison_text': comparison_row['text'],
                'model_a': comparison_row.get('model_a'),
                'model_b': comparison_row.get('model_b'),
                'summary_a_id': comparison_row.get('summary_a_id'),
                'summary_b_id': comparison_row.get('summary_b_id'),
                'summary_a_text': comparison_row.get('summary_a_text'),
                'summary_b_text': comparison_row.get('summary_b_text')
            })
            if i < 20 or i % 200 == 0:
                print(f"  -> Added pair comparison")
        else:
            if i < 20 or i % 200 == 0:
                print(f"  -> Skipped: base_id_match={question_base_id == comparison_base_id}, model_check={question_row['model'] == 'question'}")

print(f"Extracted {len(rating_pairs)} rating pairs")
print(f"Extracted {len(pair_comparisons)} comparison pairs")

# Convert to DataFrames for easier joining
rating_pairs_df = pd.DataFrame(rating_pairs)
pair_comparisons_df = pd.DataFrame(pair_comparisons)
# Out:
# Understanding data structure...
# Rating data: 1500 total rows
# Pair data: 2250 total rows
# Debugging pair data structure...
# First few rows of pair_df:
#                                   id                             raw_id  \
# 0  38a9bde51b2e82b9_7cb5806a4aa6f3ff  38a9bde51b2e82b9_7cb5806a4aa6f3ff
# 1  38a9bde51b2e82b9_8172525bd422435b  38a9bde51b2e82b9_8172525bd422435b
# 2  38a9bde51b2e82b9_97800d729fb0bca1  38a9bde51b2e82b9_97800d729fb0bca1
# 3  7cb5806a4aa6f3ff_8172525bd422435b  7cb5806a4aa6f3ff_8172525bd422435b
# 4  7cb5806a4aa6f3ff_97800d729fb0bca1  7cb5806a4aa6f3ff_97800d729fb0bca1
# 5  7cb5806a4aa6f3ff_a368f52fd450713b  7cb5806a4aa6f3ff_a368f52fd450713b
# 6  8172525bd422435b_97800d729fb0bca1  8172525bd422435b_97800d729fb0bca1
# 7  8172525bd422435b_a368f52fd450713b  8172525bd422435b_a368f52fd450713b
# 8  8172525bd422435b_ad3135722c23a68f  8172525bd422435b_ad3135722c23a68f
# 9  97800d729fb0bca1_a368f52fd450713b  97800d729fb0bca1_a368f52fd450713b
#
#                                             question  \
# 0  Do you support requiring real-name registratio...
# 1  Do you support requiring real-name registratio...
# 2  Do you support requiring real-name registratio...
# 3  Do you support requiring real-name registratio...
# 4  Do you support requiring real-name registratio...
# 5  Do you support requiring real-name registratio...
# 6  Do you support requiring real-name registratio...
# 7  Do you support requiring real-name registratio...
# 8  Do you support requiring real-name registratio...
# 9  Do you support requiring real-name registratio...
#
#                                                 text       model  \
# 0  <h4>Two summaries of opinions are shown below....  comparison
# 1  <h4>Two summaries of opinions are shown below....  comparison
# 2  <h4>Two summaries of opinions are shown below....  comparison
# 3  <h4>Two summaries of opinions are shown below....  comparison
# 4  <h4>Two summaries of opinions are shown below....  comparison
# 5  <h4>Two summaries of opinions are shown below....  comparison
# 6  <h4>Two summaries of opinions are shown below....  comparison
# 7  <h4>Two summaries of opinions are shown below....  comparison
# 8  <h4>Two summaries of opinions are shown below....  comparison
# 9  <h4>Two summaries of opinions are shown below....  comparison
#
#    num_samples_group  summary_length  model_a  model_b      summary_a_id  \
# 0                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 1                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 2                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 3                 10             NaN      NaN      NaN  7cb5806a4aa6f3ff
# 4                 10             NaN      NaN      NaN  7cb5806a4aa6f3ff
# 5                 10             NaN      NaN      NaN  7cb5806a4aa6f3ff
# 6                 10             NaN      NaN      NaN  8172525bd422435b
# 7                 10             NaN      NaN      NaN  8172525bd422435b
# 8                 10             NaN      NaN      NaN  8172525bd422435b
# 9                 10             NaN      NaN      NaN  97800d729fb0bca1
#
#        summary_b_id  summary_a_text  summary_b_text  summary_length_a  \
# 0  7cb5806a4aa6f3ff             NaN             NaN               NaN
# 1  8172525bd422435b             NaN             NaN               NaN
# 2  97800d729fb0bca1             NaN             NaN               NaN
# 3  8172525bd422435b             NaN             NaN               NaN
# 4  97800d729fb0bca1             NaN             NaN               NaN
# 5  a368f52fd450713b             NaN             NaN               NaN
# 6  97800d729fb0bca1             NaN             NaN               NaN
# 7  a368f52fd450713b             NaN             NaN               NaN
# 8  ad3135722c23a68f             NaN             NaN               NaN
# 9  a368f52fd450713b             NaN             NaN               NaN
#
#    summary_length_b
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
#
# Checking model column values:
# model
# comparison    2250
# Name: count, dtype: int64
# Row 0: model='comparison', raw_id='38a9bde51b2e82b9_7cb5806a4aa6f3ff'
# Row 1: model='comparison', raw_id='38a9bde51b2e82b9_8172525bd422435b'
#   Comparing: '38a9bde51b2e82b9_7cb5806a4aa6f3ff' == '38a9bde51b2e82b9_8172525bd422435b'
#   -> Skipped: base_id_match=False, model_check=False
# Row 2: model='comparison', raw_id='38a9bde51b2e82b9_97800d729fb0bca1'
# Row 3: model='comparison', raw_id='7cb5806a4aa6f3ff_8172525bd422435b'
#   Comparing: '38a9bde51b2e82b9_97800d729fb0bca1' == '7cb5806a4aa6f3ff_8172525bd422435b'
#   -> Skipped: base_id_match=False, model_check=False
# Row 4: model='comparison', raw_id='7cb5806a4aa6f3ff_97800d729fb0bca1'
# Row 5: model='comparison', raw_id='7cb5806a4aa6f3ff_a368f52fd450713b'
#   Comparing: '7cb5806a4aa6f3ff_97800d729fb0bca1' == '7cb5806a4aa6f3ff_a368f52fd450713b'
#   -> Skipped: base_id_match=False, model_check=False
# Row 6: model='comparison', raw_id='8172525bd422435b_97800d729fb0bca1'
# Row 7: model='comparison', raw_id='8172525bd422435b_a368f52fd450713b'
#   Comparing: '8172525bd422435b_97800d729fb0bca1' == '8172525bd422435b_a368f52fd450713b'
#   -> Skipped: base_id_match=False, model_check=False
# Row 8: model='comparison', raw_id='8172525bd422435b_ad3135722c23a68f'
# Row 9: model='comparison', raw_id='97800d729fb0bca1_a368f52fd450713b'
#   Comparing: '8172525bd422435b_ad3135722c23a68f' == '97800d729fb0bca1_a368f52fd450713b'
#   -> Skipped: base_id_match=False, model_check=False
# Row 10: model='comparison', raw_id='97800d729fb0bca1_ad3135722c23a68f'
# Row 11: model='comparison', raw_id='97800d729fb0bca1_b2c3275416c437cc'
#   Comparing: '97800d729fb0bca1_ad3135722c23a68f' == '97800d729fb0bca1_b2c3275416c437cc'
#   -> Skipped: base_id_match=False, model_check=False
# Row 12: model='comparison', raw_id='a368f52fd450713b_ad3135722c23a68f'
# Row 13: model='comparison', raw_id='a368f52fd450713b_b2c3275416c437cc'
#   Comparing: 'a368f52fd450713b_ad3135722c23a68f' == 'a368f52fd450713b_b2c3275416c437cc'
#   -> Skipped: base_id_match=False, model_check=False
# Row 14: model='comparison', raw_id='a368f52fd450713b_b47684688d868a0f'
# Row 15: model='comparison', raw_id='ad3135722c23a68f_b2c3275416c437cc'
#   Comparing: 'a368f52fd450713b_b47684688d868a0f' == 'ad3135722c23a68f_b2c3275416c437cc'
#   -> Skipped: base_id_match=False, model_check=False
# Row 16: model='comparison', raw_id='ad3135722c23a68f_b47684688d868a0f'
# Row 17: model='comparison', raw_id='ad3135722c23a68f_bcf20dbee5035406'
#   Comparing: 'ad3135722c23a68f_b47684688d868a0f' == 'ad3135722c23a68f_bcf20dbee5035406'
#   -> Skipped: base_id_match=False, model_check=False
# Row 18: model='comparison', raw_id='b2c3275416c437cc_b47684688d868a0f'
# Row 19: model='comparison', raw_id='b2c3275416c437cc_bcf20dbee5035406'
#   Comparing: 'b2c3275416c437cc_b47684688d868a0f' == 'b2c3275416c437cc_bcf20dbee5035406'
#   -> Skipped: base_id_match=False, model_check=False
# Row 200: model='comparison', raw_id='60ed0c3a8aa47a8d_ad06843babdcceca'
# Row 201: model='comparison', raw_id='65818b34ad517f76_6cb59535e826d69f'
#   Comparing: '60ed0c3a8aa47a8d_ad06843babdcceca' == '65818b34ad517f76_6cb59535e826d69f'
#   -> Skipped: base_id_match=False, model_check=False
# Row 400: model='comparison', raw_id='dafb08821de1fcb3_259c82b38208d8a7'
# Row 401: model='comparison', raw_id='dafb08821de1fcb3_54eb4e4777e5186e'
#   Comparing: 'dafb08821de1fcb3_259c82b38208d8a7' == 'dafb08821de1fcb3_54eb4e4777e5186e'
#   -> Skipped: base_id_match=False, model_check=False
# Row 600: model='comparison', raw_id='7b1a61f08d64ea99_7eb6ea2fc9e4bf5b'
# Row 601: model='comparison', raw_id='7b1a61f08d64ea99_89d2b2b83b676275'
#   Comparing: '7b1a61f08d64ea99_7eb6ea2fc9e4bf5b' == '7b1a61f08d64ea99_89d2b2b83b676275'
#   -> Skipped: base_id_match=False, model_check=False
# Row 800: model='comparison', raw_id='c83c1f250a50b137_f9c5ff1fe967c485'
# Row 801: model='comparison', raw_id='d9eb1eab4db5b377_eeb5abd885166f2b'
#   Comparing: 'c83c1f250a50b137_f9c5ff1fe967c485' == 'd9eb1eab4db5b377_eeb5abd885166f2b'
#   -> Skipped: base_id_match=False, model_check=False
# Row 1000: model='comparison', raw_id='3771ed8c5b130af3_61dd546c78c8eca6'
# Row 1001: model='comparison', raw_id='3771ed8c5b130af3_7a3d6a9bbf23987f'
#   Comparing: '3771ed8c5b130af3_61dd546c78c8eca6' == '3771ed8c5b130af3_7a3d6a9bbf23987f'
#   -> Skipped: base_id_match=False, model_check=False
# Row 1200: model='comparison', raw_id='b37e57f739933393_c0bb1137c3af4a19'
# Row 1201: model='comparison', raw_id='b37e57f739933393_cc30c0e21b8c71cf'
#   Comparing: 'b37e57f739933393_c0bb1137c3af4a19' == 'b37e57f739933393_cc30c0e21b8c71cf'
#   -> Skipped: base_id_match=False, model_check=False
# Row 1400: model='comparison', raw_id='225708bdc25d66bd_41ce49b94f2e8311'
# Row 1401: model='comparison', raw_id='25db8c4f7669aef7_38c181654c373b62'
#   Comparing: '225708bdc25d66bd_41ce49b94f2e8311' == '25db8c4f7669aef7_38c181654c373b62'
#   -> Skipped: base_id_match=False, model_check=False
# Row 1600: model='comparison', raw_id='757916b818c63112_a0c22961a4efe7b4'
# Row 1601: model='comparison', raw_id='757916b818c63112_a49521477f4745c2'
#   Comparing: '757916b818c63112_a0c22961a4efe7b4' == '757916b818c63112_a49521477f4745c2'
#   -> Skipped: base_id_match=False, model_check=False
# Row 1800: model='comparison', raw_id='1d629d0da2665b21_22525519f9b047aa'
# Row 1801: model='comparison', raw_id='1d629d0da2665b21_457189544fce25fc'
#   Comparing: '1d629d0da2665b21_22525519f9b047aa' == '1d629d0da2665b21_457189544fce25fc'
#   -> Skipped: base_id_match=False, model_check=False
# Row 2000: model='comparison', raw_id='9214e450a110a68f_c0b1964256d2d970'
# Row 2001: model='comparison', raw_id='a004256fdce82a7b_b4bb841ff25d6855'
#   Comparing: '9214e450a110a68f_c0b1964256d2d970' == 'a004256fdce82a7b_b4bb841ff25d6855'
#   -> Skipped: base_id_match=False, model_check=False
# Row 2200: model='comparison', raw_id='d6ac92dede662462_18b227e0a8f483b4'
# Row 2201: model='comparison', raw_id='d6ac92dede662462_2bf06dc2beddd405'
#   Comparing: 'd6ac92dede662462_18b227e0a8f483b4' == 'd6ac92dede662462_2bf06dc2beddd405'
#   -> Skipped: base_id_match=False, model_check=False
# Extracted 750 rating pairs
# Extracted 0 comparison pairs

# %%
# Build triplet_df from ring_df (question + rating(summary_a_id) + comparison)
import pandas as pd
from pathlib import Path

rating_src = Path('/home/ec2-user/LLMs-Scalable-Deliberation/annotation/summary-rating/data_files/processed/sum_humanstudy_rating_full.csv')
if 'ring_df' not in globals():
    # Fallback: load the ring pairs file
    ring_path = Path('/home/ec2-user/LLMs-Scalable-Deliberation/annotation/summary-rating/data_files/processed/sum_humanstudy_pair_full_ring.csv')
    ring_df = pd.read_csv(ring_path)

if 'rating_df' not in globals():
    rating_df = pd.read_csv(rating_src)

rating_text_by_id = dict(zip(rating_df['id'].astype(str), rating_df['text']))

triplet_rows = []
for idx, row in ring_df.iterrows():
    question = row['question']
    clean_question = (
        str(question)
        .replace(' Please answer briefly in 2–3 sentences.', '')
        .replace('Please answer briefly in 1–2 sentences.', '')
    )
    triplet_id = f'triplet_ring_{idx}'

    # Row 1: Question
    triplet_rows.append({
        'id': f'{triplet_id}_question',
        'raw_id': row['raw_id'],
        'question': question,
        'text': f'<h3>[Question]</h3><h4>{clean_question}</h4>',
        'type': 'question',
        'model': 'question',
        'num_samples_group': row.get('num_samples_group'),
        'summary_length': None,
        'model_a': None,
        'model_b': None,
        'summary_a_id': None,
        'summary_b_id': None,
        'summary_a_text': None,
        'summary_b_text': None,
        'summary_length_a': None,
        'summary_length_b': None,
    })

    # Row 2: Rating for summary_a_id
    a_id = str(row['summary_a_id'])
    rating_text = rating_text_by_id.get(a_id, '')
    triplet_rows.append({
        'id': f'{triplet_id}_rating',
        'raw_id': row['raw_id'],
        'question': question,
        'text': rating_text,
        'type': 'rating',
        'model': row.get('model_a', 'rating'),
        'num_samples_group': row.get('num_samples_group'),
        'summary_length': None,
        'model_a': row.get('model_a'),
        'model_b': row.get('model_b'),
        'summary_a_id': row.get('summary_a_id'),
        'summary_b_id': row.get('summary_b_id'),
        'summary_a_text': row.get('summary_a_text'),
        'summary_b_text': row.get('summary_b_text'),
        'summary_length_a': row.get('summary_length_a'),
        'summary_length_b': row.get('summary_length_b'),
    })

    # Row 3: Comparison (ring pair HTML)
    triplet_rows.append({
        'id': f'{triplet_id}_comparison',
        'raw_id': row['raw_id'],
        'question': question,
        'text': row['text'],
        'type': 'comparison',
        'model': 'comparison',
        'num_samples_group': row.get('num_samples_group'),
        'summary_length': row.get('summary_length'),
        'model_a': row.get('model_a'),
        'model_b': row.get('model_b'),
        'summary_a_id': row.get('summary_a_id'),
        'summary_b_id': row.get('summary_b_id'),
        'summary_a_text': row.get('summary_a_text'),
        'summary_b_text': row.get('summary_b_text'),
        'summary_length_a': row.get('summary_length_a'),
        'summary_length_b': row.get('summary_length_b'),
    })

triplet_df = pd.DataFrame(triplet_rows)

# %%
# Debug and save (your provided block)
print("\nDebugging triplet_df structure:")
print(f"triplet_df shape: {triplet_df.shape}")
print(f"triplet_df columns: {triplet_df.columns.tolist()}")
print(f"First few rows:")
print(triplet_df.head())

# Check if triplet_df is empty
if len(triplet_df) == 0:
    print("ERROR: triplet_df is empty! Check the matching process.")
else:
    # Verify the triplet structure and show samples
    print("\nVerifying triplet structure:")
    if 'type' in triplet_df.columns:
        print(f"Question entries: {len(triplet_df[triplet_df['type'] == 'question'])}")
        print(f"Rating entries: {len(triplet_df[triplet_df['type'] == 'rating'])}")  
        print(f"Comparison entries: {len(triplet_df[triplet_df['type'] == 'comparison'])}")
        
        # Show sample triplets
        print("\nSample triplet structure:")
        for i in range(0, min(9, len(triplet_df)), 3):
            print(f"\nTriplet {i//3 + 1}:")
            print(f"  Question: {triplet_df.iloc[i]['text']}")
            print(f"  Rating: {triplet_df.iloc[i+1]['text'][:100]}...")
            if i+2 < len(triplet_df):
                print(f"  Comparison: {triplet_df.iloc[i+2]['text'][:100]}...")
    else:
        print("ERROR: 'type' column missing from triplet_df")

# Save the triplet data
output_path = '../data_files/processed/sum_humanstudy_triplet_full_ring.csv'
triplet_df.to_csv(output_path, index=False)
print(f"\nSaved triplet data to: {output_path}")
print(f"Total rows: {len(triplet_df)}")
print(f"Total triplets: {len(triplet_df) // 3}")

# Final verification
triplet_count = len(triplet_df) // 3
remainder = len(triplet_df) % 3
if remainder == 0:
    print(f"✅ Perfect triplet structure: {triplet_count} complete triplets")
else:
    print(f"⚠️ Incomplete triplets: {triplet_count} complete + {remainder} remaining entries")
# Out:
# Debugging triplet_df structure:
# triplet_df shape: (6750, 16)
# triplet_df columns: ['id', 'raw_id', 'question', 'text', 'type', 'model', 'num_samples_group', 'summary_length', 'model_a', 'model_b', 'summary_a_id', 'summary_b_id', 'summary_a_text', 'summary_b_text', 'summary_length_a', 'summary_length_b']
# First few rows:
#                           id                             raw_id  \
# 0    triplet_ring_0_question  38a9bde51b2e82b9_7cb5806a4aa6f3ff
# 1      triplet_ring_0_rating  38a9bde51b2e82b9_7cb5806a4aa6f3ff
# 2  triplet_ring_0_comparison  38a9bde51b2e82b9_7cb5806a4aa6f3ff
# 3    triplet_ring_1_question  38a9bde51b2e82b9_8172525bd422435b
# 4      triplet_ring_1_rating  38a9bde51b2e82b9_8172525bd422435b
#
#                                             question  \
# 0  Do you support requiring real-name registratio...
# 1  Do you support requiring real-name registratio...
# 2  Do you support requiring real-name registratio...
# 3  Do you support requiring real-name registratio...
# 4  Do you support requiring real-name registratio...
#
#                                                 text        type       model  \
# 0  <h3>[Question]</h3><h4>Do you support requirin...    question    question
# 1                                                         rating         NaN
# 2  <h4>Two summaries of opinions are shown below....  comparison  comparison
# 3  <h3>[Question]</h3><h4>Do you support requirin...    question    question
# 4                                                         rating         NaN
#
#    num_samples_group  summary_length  model_a  model_b      summary_a_id  \
# 0                 10             NaN      NaN      NaN              None
# 1                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 2                 10             NaN      NaN      NaN  38a9bde51b2e82b9
# 3                 10             NaN      NaN      NaN              None
# 4                 10             NaN      NaN      NaN  38a9bde51b2e82b9
#
#        summary_b_id  summary_a_text  summary_b_text  summary_length_a  \
# 0              None             NaN             NaN               NaN
# 1  7cb5806a4aa6f3ff             NaN             NaN               NaN
# 2  7cb5806a4aa6f3ff             NaN             NaN               NaN
# 3              None             NaN             NaN               NaN
# 4  8172525bd422435b             NaN             NaN               NaN
#
#    summary_length_b
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# Verifying triplet structure:
# Question entries: 2250
# Rating entries: 2250
# Comparison entries: 2250
#
# Sample triplet structure:
#
# Triplet 1:
#   Question: <h3>[Question]</h3><h4>Do you support requiring real-name registration on social media platforms, where users must register and post under their real identity?</h4>
#   Rating: ...
#   Comparison: <h4>Two summaries of opinions are shown below. Read carefully and answer according to your prior opi...
#
# Triplet 2:
#   Question: <h3>[Question]</h3><h4>Do you support requiring real-name registration on social media platforms, where users must register and post under their real identity?</h4>
#   Rating: ...
#   Comparison: <h4>Two summaries of opinions are shown below. Read carefully and answer according to your prior opi...
#
# Triplet 3:
#   Question: <h3>[Question]</h3><h4>Do you support requiring real-name registration on social media platforms, where users must register and post under their real identity?</h4>
#   Rating: ...
#   Comparison: <h4>Two summaries of opinions are shown below. Read carefully and answer according to your prior opi...
#
# Saved triplet data to: ../data_files/processed/sum_humanstudy_triplet_full_ring.csv
# Total rows: 6750
# Total triplets: 2250
# ✅ Perfect triplet structure: 2250 complete triplets

# %%
len(processed_pair_data)
